# %%
import h5py
import numpy as np
import os
import glob

def merge_hdf5_files(file_list, output_file):
    object_ids = set()
    with h5py.File(output_file, "w") as hdf_out:
        for file_path in file_list:
                try:
                    with h5py.File(file_path, "r") as hdf_in:
                        print(f"File {file_path}: {len(hdf_in.keys())}")
                        object_ids.update(hdf_in.keys())
                        for group_name in hdf_in.keys():
                            #print(f"Processing group: {group_name}")
                            if group_name in hdf_out:
                                del hdf_out[group_name]  # Overwrite existing group
                            hdf_in.copy(group_name, hdf_out)
                except Exception as e:
                    print(f"For file: {file_path}, Error merging files: {e}")
                    continue
    print(f"Merged {len(file_list)} files into {output_file}")
    print(f"Unique object IDs: {len(object_ids)}")

file_prefix_list = [
    "data/aug8_stone_N10w1000s500t6c4/",
]

file_list = []
for file_prefix in file_prefix_list:
    file_list += glob.glob(file_prefix+"job*.h5")
    print(file_list)

print(f"Found {len(file_list)} files to merge.")

merge_hdf5_files(
    file_list=file_list,
    output_file="data/aug8_stone_N10w1000s500t6c4_merged.h5"
)
# Out:
# ['data/aug8_stone_N10w1000s500t6c4/job0.h5', 'data/aug8_stone_N10w1000s500t6c4/job17.h5', 'data/aug8_stone_N10w1000s500t6c4/job18.h5', 'data/aug8_stone_N10w1000s500t6c4/job4.h5', 'data/aug8_stone_N10w1000s500t6c4/job3.h5', 'data/aug8_stone_N10w1000s500t6c4/job12.h5', 'data/aug8_stone_N10w1000s500t6c4/job16.h5', 'data/aug8_stone_N10w1000s500t6c4/job13.h5', 'data/aug8_stone_N10w1000s500t6c4/job1.h5', 'data/aug8_stone_N10w1000s500t6c4/job6.h5', 'data/aug8_stone_N10w1000s500t6c4/job9.h5', 'data/aug8_stone_N10w1000s500t6c4/job11.h5', 'data/aug8_stone_N10w1000s500t6c4/job7.h5', 'data/aug8_stone_N10w1000s500t6c4/job2.h5', 'data/aug8_stone_N10w1000s500t6c4/job8.h5', 'data/aug8_stone_N10w1000s500t6c4/job14.h5', 'data/aug8_stone_N10w1000s500t6c4/job15.h5', 'data/aug8_stone_N10w1000s500t6c4/job10.h5', 'data/aug8_stone_N10w1000s500t6c4/job5.h5']
# Found 19 files to merge.
# File data/aug8_stone_N10w1000s500t6c4/job0.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job17.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job18.h5: 9
# File data/aug8_stone_N10w1000s500t6c4/job4.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job3.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job12.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job16.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job13.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job1.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job6.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job9.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job11.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job7.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job2.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job8.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job14.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job15.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job10.h5: 10
# File data/aug8_stone_N10w1000s500t6c4/job5.h5: 10
# Merged 19 files into data/aug8_stone_N10w1000s500t6c4_merged.h5
# Unique object IDs: 189

# %%
def read_quasars_from_hdf5(file_path):
    quasar_list = []
    with h5py.File(file_path, "r") as hdf:
        for group_name in hdf.keys():
            group = hdf[group_name]
            quasar = {"object_id": group_name}
            for key, value in group.attrs.items():
                quasar[key] = value
            for sub_group_name in group.keys():
                sub_group = group[sub_group_name]
                quasar[sub_group_name] = {sub_key: sub_group[sub_key][...] for sub_key in sub_group.keys()}
            quasar_list.append(quasar)
    return quasar_list


quasar_list = read_quasars_from_hdf5(file_prefix+"merged.h5")
print(len(quasar_list))
# Out:
# 180

# %%
file_list = glob.glob(file_prefix+"job*.h5")
job_ids = [os.path.splitext(os.path.basename(f))[0].split("_")[-1][3:] for f in file_list]
job_ids_int = [int(j) for j in job_ids]
missing_ids = [i for i in range(0, 28) if i not in job_ids_int]
print("Missing job ids:", missing_ids)
# Out:
# Missing job ids: [5, 7, 10, 27]
