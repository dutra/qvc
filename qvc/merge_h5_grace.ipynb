# %%
import h5py
import numpy as np
import os
import glob

def merge_hdf5_files(file_list, output_file, N):
    object_ids = set()
    with h5py.File(output_file, "w") as hdf_out:
        for file_path in file_list:
                try:
                    with h5py.File(file_path, "r") as hdf_in:
                        if len(hdf_in.keys()) != N:
                            print(f"File {file_path} has {len(hdf_in.keys())} entries, expected {N}. Skipping.")
                            continue
                        print(f"File {file_path}: {len(hdf_in.keys())}")
                        object_ids.update(hdf_in.keys())
                        for group_name in hdf_in.keys():
                            #print(f"Processing group: {group_name}")
                            if group_name in hdf_out:
                                del hdf_out[group_name]  # Overwrite existing group
                            hdf_in.copy(group_name, hdf_out)
                except Exception as e:
                    print(f"For file: {file_path}, Error merging files: {e}")
                    continue
    print(f"Merged {len(file_list)} files into {output_file}")
    print(f"Unique object IDs: {len(object_ids)}")

file_prefix_list = [
    "results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/",
]

file_list = []
for file_prefix in file_prefix_list:
    file_list += glob.glob(file_prefix+"job*.h5")
    print(file_list)

print(f"Found {len(file_list)} files to merge.")

merge_hdf5_files(
    file_list=file_list,
    output_file="results/data/aug14_stone_qs_cpu_N20w2000s500t8c2.h5",
    N=20

)
# Out:
# ['results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job0.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job4.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job3.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job1.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job6.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job9.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job7.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job2.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job8.h5', 'results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job5.h5']
# Found 10 files to merge.
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job0.h5: 20
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job4.h5: 20
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job3.h5: 20
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job1.h5: 20
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job6.h5: 20
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job9.h5 has 9 entries, expected 20. Skipping.
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job7.h5: 20
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job2.h5: 20
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job8.h5: 20
# File results/data/aug14_stone_qs_cpu_N20w2000s500t8c2/job5.h5: 20
# Merged 10 files into results/data/aug14_stone_qs_cpu_N20w2000s500t8c2.h5
# Unique object IDs: 180

# %%
def read_quasars_from_hdf5(file_path):
    quasar_list = []
    with h5py.File(file_path, "r") as hdf:
        for group_name in hdf.keys():
            group = hdf[group_name]
            quasar = {"object_id": group_name}
            for key, value in group.attrs.items():
                quasar[key] = value
            for sub_group_name in group.keys():
                sub_group = group[sub_group_name]
                quasar[sub_group_name] = {sub_key: sub_group[sub_key][...] for sub_key in sub_group.keys()}
            quasar_list.append(quasar)
    return quasar_list


quasar_list = read_quasars_from_hdf5(file_prefix+"merged.h5")
print(len(quasar_list))
# Out:
# 180

# %%
file_list = glob.glob(file_prefix+"job*.h5")
job_ids = [os.path.splitext(os.path.basename(f))[0].split("_")[-1][3:] for f in file_list]
job_ids_int = [int(j) for j in job_ids]
missing_ids = [i for i in range(0, 28) if i not in job_ids_int]
print("Missing job ids:", missing_ids)
# Out:
# Missing job ids: [5, 7, 10, 27]
