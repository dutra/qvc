# %%
from hubble_utils import load_agn_data, read_quasars_from_hdf5
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
import warnings
warnings.filterwarnings("ignore")
plt.style.use('style.mplstyle')

# %%
spectra_fit_csv = "results/data/nov12a_11c_single_scratch_nov10a_carma_removemix_fixmeanband_no1pluszflux2L_freeiron_mc50_best.csv"
h5_file = "results/data/nov10a_single_chisq_carma_mixscalar_nozband_highertaufastlim_removemix_fixband_lagblrband_chisq_spl_nofhost_bwb_lmc-6_N1w1000s200t14ch4.h5"

prefix = "nov11a_nov9a_oct10a_preview_fhost0_dev_redchi2.0cut_carma_spl_fasttest_changemask_zsigma04"

from types import SimpleNamespace

df_agn, df_agn_all = load_agn_data(h5_file,
                       fhost_cut=0.0,
                       only_load=False,
                       spectra_fit_csv=[spectra_fit_csv],
                       zquery_csv='results/data/sep19_chisq_zquery.csv',
                       sdss_mags_csv="results/data/nov2_sdss_mags.csv",
                       iron_frac_cut=10.0,
                       redchi2_cut=2.0,)
# Out:
# Number of quasars loaded: 13090
# Entire Sample file length: 13193
# Populating spectra fit data from: ['results/data/nov12a_11c_single_scratch_nov10a_carma_removemix_fixmeanband_no1pluszflux2L_freeiron_mc50_best.csv']
# Loading spectra fit CSV (1/1): results/data/nov12a_11c_single_scratch_nov10a_carma_removemix_fixmeanband_no1pluszflux2L_freeiron_mc50_best.csv
# Length of merged DataFrame (best=True): 13090
# Cut on apparent_mag_2500 : 259 objects removed
# Populating zquery data from: results/data/sep19_chisq_zquery.csv
# -------------------------- Z query report --------------------------
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

lambda_pivot = {
    'u': 3543,  # SDSS u-band
    'g': 4770,  # SDSS g-band
    'r': 6231,  # SDSS r-band
    'i': 7625,  # SDSS i-band
    'z': 9134,  # SDSS z-band
    'y': 9633,  # PS1 y-band
}

colors = {
    'u': 'tab:blue',
    'g': 'tab:green', 
    'r': 'tab:orange', 
    'i': 'tab:red', 
    'z': 'tab:brown', 
    'y': 'tab:gray'
}

def log_broken_pl(lam, lam_s, d1, d2, ds):
    """
    Log10 of a smooth broken power-law, normalized to 0 at lam_s.
    ds is a smoothness (larger ds => smoother transition).
    This version is numerically stable and AD-friendly.
    Preconditions: lam>0, lam_s>0, ds>0
    """
    ln10 = np.log(10.0)

    # log10(x) with x = lam/lam_s
    log10x = (np.log(lam) - np.log(lam_s)) / ln10

    # a = log10(x)/ds; need log10(1 + 10^a) stably
    a = log10x / ds
    # log10(1 + 10^a) = log(1 + exp(a*ln10))/ln10
    log10_1p10a = np.logaddexp(0.0, a * ln10) / ln10

    delta = d2 - d1
    # smooth_exp = 1/ds
    # => contribution = (delta*ds)*(log10_1p10a - log10(2))
    log_f = d1 * log10x + (delta * ds) * (log10_1p10a - np.log10(2.0))
    return log_f


def _global_intercept(y, lam, w, lam_s, d1, d2, ds):
    """
    Weighted global intercept α so that y ≈ α + f(λ),
    f is the smooth broken power-law with (d1,d2,ds).
    α = (Σ w * (y - f)) / (Σ w)
    """
    f = log_broken_pl(lam, lam_s, d1, d2, ds)
    den = np.sum(w)
    if not np.isfinite(den) or den <= 0:
        den = 1.0
    return float(np.sum(w * (y - f)) / den)


def _hessian_num(fun, x0, eps=1e-3):
    """
    Central-difference numerical Hessian with per-parameter relative steps.
    eps is interpreted as a *relative* step size; actual step is
        h_i = eps * max(1, |x0_i|)
    """
    x0 = np.asarray(x0, float)
    n  = x0.size
    H  = np.zeros((n, n), float)
    h  = eps * np.maximum(1.0, np.abs(x0))
    for i in range(n):
        ei = np.zeros(n); ei[i] = h[i]
        for j in range(n):
            ej = np.zeros(n); ej[j] = h[j]
            fpp = fun(x0 + ei + ej)
            fpm = fun(x0 + ei - ej)
            fmp = fun(x0 - ei + ej)
            fmm = fun(x0 - ei - ej)
            H[i, j] = (fpp - fpm - fmp + fmm) / (4.0 * h[i] * h[j])
    H = 0.5 * (H + H.T)
    return H


def _profile_intercepts(y, f, w, gid):
    """
    For fixed f(λ), solve for optimal per-object intercepts α_g via weighted means
    of (y - f). Returns model values m and weighted SSE = Σ w * (y - m)^2.
    """
    G = gid.max() + 1
    num = np.zeros(G, float)
    den = np.zeros(G, float)

    r = y - f
    np.add.at(num, gid, w * r)
    np.add.at(den, gid, w)

    den = np.where(den > 0, den, 1.0)
    alpha = num / den

    m = alpha[gid] + f
    sse = np.sum(w * (y - m) ** 2)
    return m, sse


def _collect_xy_full(df, bands, *, target, lambda_pivot):
    """
    Build arrays across all rows and bands.

    Returns:
        lam      : rest-frame wavelength [Å]
        y        : log_sigma_band_* or log_tau_band_*_RF
        yerr     : the quoted per-point 1σ error (same units as y)
        w        : weights = 1/yerr^2 (with floor)
        gid      : per-object integer ID for profiling intercepts
    """
    if target == "sigma":
        ystem = "log_sigma_band_{}"
        estem = "log_sigma_band_{}_err"
    elif target == "tau":
        ystem = "log_tau_band_{}_RF"
        estem = "log_tau_band_{}_RF_err"
    else:
        raise ValueError("target must be 'sigma' or 'tau'.")

    lam, y, yerr, w, gid = [], [], [], [], []
    for gi, (_, row) in enumerate(df.iterrows()):
        z = float(row["z"])
        for b in bands:
            if b not in lambda_pivot:
                continue
            col = ystem.format(b)
            if col not in df:
                continue

            lam_rf = float(lambda_pivot[b]) / (1.0 + z)
            yi     = float(row[col])
            if not (np.isfinite(lam_rf) and np.isfinite(yi)):
                continue

            # measurement error
            err_col = estem.format(b)
            ei = np.nan
            if err_col in df:
                ei = float(row[err_col])
            # guardrails
            if not (np.isfinite(ei) and (ei > 0)):
                ei = 1e6  # effectively "infinite" error -> near-zero weight

            wt = 1.0 / max(ei * ei, 1e-12)

            lam.append(lam_rf)
            y.append(yi)
            yerr.append(ei)
            w.append(wt)
            gid.append(gi)

    lam  = np.asarray(lam,  float)
    y    = np.asarray(y,    float)
    yerr = np.asarray(yerr, float)
    w    = np.asarray(w,    float)
    gid  = np.asarray(gid,  int)

    if lam.size < 3:
        raise ValueError(f"Insufficient points for {target}: {lam.size}")
    return lam, y, yerr, w, gid


def _objective(theta, lam, y, w, gid, lam_s, *, fit_ds=True, ds_fixed=0.1):
    """
    Half the weighted SSE after profiling out per-object intercepts.
    """
    if fit_ds:
        d1, d2, ds = float(theta[0]), float(theta[1]), float(theta[2])
        ds = max(ds, 1e-3)
    else:
        d1, d2 = float(theta[0]), float(theta[1])
        ds = float(ds_fixed)
        ds = max(ds, 1e-3)

    f = log_broken_pl(lam, lam_s, d1, d2, ds)
    _, sse = _profile_intercepts(y, f, w, gid)
    return 0.5 * sse


def _run_optimizer(obj, init, bounds, fit_ds):
    """
    Shared thin wrapper so we can call it many times (bootstrap).
    """
    try:
        import scipy.optimize as so
        x0   = np.asarray(init if fit_ds else init[:2], float)
        bnds = bounds if fit_ds else (bounds[0], bounds[1])
        res  = so.minimize(obj, x0=x0, method="L-BFGS-B", bounds=bnds)
        theta  = res.x
        method = "scipy(L-BFGS-B)"
        success = bool(res.success)
    except Exception:
        # brute grid fallback
        method, success = "grid", True
        d1g = np.linspace(bounds[0][0], bounds[0][1], 41)
        d2g = np.linspace(bounds[1][0], bounds[1][1], 41)
        if fit_ds:
            dsg = np.linspace(bounds[2][0], bounds[2][1], 31)
            best = (np.inf, 0.0, 0.0, max(init[2], 1e-3))
            for d1 in d1g:
                for d2 in d2g:
                    for ds in dsg:
                        val = obj((d1, d2, ds))
                        if val < best[0]:
                            best = (val, d1, d2, ds)
            theta = np.array([best[1], best[2], best[3]], float)
        else:
            best = (np.inf, 0.0, 0.0)
            for d1 in d1g:
                for d2 in d2g:
                    val = obj((d1, d2))
                    if val < best[0]:
                        best = (val, d1, d2)
            theta = np.array([best[1], best[2]], float)

    return theta, method, success


def fit_slopes_broken(
    df, bands, *, lambda_pivot,
    lam_s=2500.0,
    init=(0.0, 0.0, 0.1),
    bounds=((-6, 6), (-6, 6), (1e-3, 3.0)),
    target="sigma",
    return_errors=True,
    fit_ds=True,
    ds_fixed=0.1,
    cov_scale="redchi",     # "redchi" | "none" | float
    min_scale=None,
    n_boot=300,
    rng_seed=42,
):
    """
    Same as before, but now we ALSO return:
      - 'boot_thetas': array of shape (n_boot_eff, 3) with (d1,d2,ds) from each
        successful bootstrap refit. ds is included even if ds was fixed.
    """
    # ---- collect data ----
    lam, y, yerr, w, gid = _collect_xy_full(df, bands, target=target, lambda_pivot=lambda_pivot)

    # objective closure for the main data
    obj = (lambda th: _objective(th, lam, y, w, gid, lam_s, fit_ds=fit_ds, ds_fixed=ds_fixed))

    # ---- main fit ----
    theta, method, success = _run_optimizer(obj, init, bounds, fit_ds)

    if fit_ds:
        d1, d2, ds = float(theta[0]), float(theta[1]), float(max(theta[2], 1e-3))
        k = 3
    else:
        d1, d2 = float(theta[0]), float(theta[1])
        ds = float(max(ds_fixed, 1e-3))
        k = 2

    # goodness-of-fit stats
    sse   = 2.0 * obj([d1, d2, ds] if fit_ds else [d1, d2])
    N     = int(y.size)
    G     = int(gid.max() + 1)
    dof   = max(1, N - G - k)
    redchi = float(sse / dof)

    out = {
        "d1": d1, "d2": d2, "ds": ds,
        "success": bool(success),
        "method": method,
        "npts": N,
        "ngroups": G,
        "dof": dof,
        "sse": float(sse),
        "redchi": redchi,
        "ds_mode": "fit" if fit_ds else "fixed",
    }

    if not return_errors:
        return out

    # ---- (1) Hessian-based covariance ----
    try:
        H = _hessian_num(
            obj,
            np.array([d1, d2, ds], float) if fit_ds else np.array([d1, d2], float),
            eps=1e-3
        )
        Hinv = np.linalg.inv(H)

        if not fit_ds:
            Hinv_full = np.full((3, 3), np.nan)
            Hinv_full[:2, :2] = Hinv
            Hinv = Hinv_full

        if cov_scale == "redchi":
            scale = redchi
        elif cov_scale == "none":
            scale = 1.0
        else:
            scale = float(cov_scale)
        if min_scale is not None:
            scale = max(scale, float(min_scale))

        cov_hess = Hinv * scale
        errs_hess = np.sqrt(np.clip(np.diag(cov_hess), 0, np.inf))

        out.update({
            "d1_err":  float(errs_hess[0]),
            "d2_err":  float(errs_hess[1]),
            "ds_err":  float(errs_hess[2]) if fit_ds else np.nan,
            "cov":     cov_hess,
            "cov_scale_used": float(scale),
        })
    except np.linalg.LinAlgError:
        out.update({
            "d1_err": np.nan, "d2_err": np.nan, "ds_err": np.nan,
            "cov": np.full((3,3), np.nan),
            "cov_scale_used": np.nan,
        })

    # ---- (2) Bootstrap over measurement errors ----
    boot_thetas_list = []
    if n_boot > 0:
        rng = np.random.default_rng(rng_seed)

        for _ in range(n_boot):
            # jitter y by its own quoted 1σ error
            y_jit = y + rng.normal(loc=0.0, scale=yerr)

            def obj_jit(th):
                return _objective(th, lam, y_jit, w, gid, lam_s,
                                  fit_ds=fit_ds, ds_fixed=ds_fixed)

            theta_b, _, ok_b = _run_optimizer(obj_jit, init, bounds, fit_ds)
            if not ok_b:
                continue

            if fit_ds:
                d1_b = float(theta_b[0])
                d2_b = float(theta_b[1])
                ds_b = float(max(theta_b[2], 1e-3))
            else:
                d1_b = float(theta_b[0])
                d2_b = float(theta_b[1])
                ds_b = float(max(ds_fixed, 1e-3))

            boot_thetas_list.append((d1_b, d2_b, ds_b))

    if len(boot_thetas_list) >= 3:
        boot_thetas = np.asarray(boot_thetas_list, float)  # (n_boot_eff, 3)
        boot_cov = np.cov(boot_thetas.T, bias=False)
        boot_errs = np.sqrt(np.clip(np.diag(boot_cov), 0, np.inf))
        out.update({
            "d1_boot_err": float(boot_errs[0]),
            "d2_boot_err": float(boot_errs[1]),
            "ds_boot_err": float(boot_errs[2]),
            "boot_cov":    boot_cov,
            "boot_thetas": boot_thetas,     # <--- NEW: save draws for plotting band
            "n_boot_eff":  int(boot_thetas.shape[0]),
        })
    else:
        out.update({
            "d1_boot_err": np.nan,
            "d2_boot_err": np.nan,
            "ds_boot_err": np.nan,
            "boot_cov":    np.full((3,3), np.nan),
            "boot_thetas": np.zeros((0,3), float),
            "n_boot_eff":  0,
        })

    return out

def fit_sigma_and_tau_slopes(
    df, bands, *, lambda_pivot, lam_s=2500.0,
    init_sigma=(0.0, 0.0, 0.1), init_tau=(0.0, 0.0, 0.1),
    bounds_sigma=((-6, 6), (-6, 6), (1e-3, 3.0)),
    bounds_tau  =((-10,10), (-10,10), (1e-3, 3.0)),
    fit_ds_sigma=True, ds_fixed_sigma=0.1,
    fit_ds_tau=True,   ds_fixed_tau=0.1,
    n_boot=300,
):
    """
    Convenience wrapper for σ and τ. We now also pass n_boot so that
    both fits report bootstrap errors.
    """
    out_sigma = fit_slopes_broken(
        df, bands, lambda_pivot=lambda_pivot, lam_s=lam_s,
        init=init_sigma, bounds=bounds_sigma, target="sigma", return_errors=True,
        fit_ds=fit_ds_sigma, ds_fixed=ds_fixed_sigma,
        n_boot=n_boot,
    )
    out_tau = fit_slopes_broken(
        df, bands, lambda_pivot=lambda_pivot, lam_s=lam_s,
        init=init_tau, bounds=bounds_tau, target="tau", return_errors=True,
        fit_ds=fit_ds_tau, ds_fixed=ds_fixed_tau,
        n_boot=n_boot,
    )
    return out_sigma, out_tau


def _jac_log_broken_pl(lam, lam_s, d1, d2, ds):
    """
    Returns derivatives (df/dd1, df/dd2, df/dds) evaluated at each lam.
    Shape: (3, n_lam). Works with lam as 1D array.
    """
    lam = np.asarray(lam, float)
    ln10 = np.log(10.0)

    Lx   = (np.log(lam) - np.log(lam_s)) / ln10         # log10(lam/lam_s)
    a    = Lx / ds                                       # a = log10x/ds
    Q    = np.logaddexp(0.0, a*ln10) / ln10              # log10(1 + 10^a)
    t    = Q - np.log10(2.0)                             # Q - log10(2)
    sigm = 1.0 / (1.0 + np.exp(-a*ln10))                 # 10^a/(1+10^a) = sigmoid(a*ln10)

    delta = (d2 - d1)

    df_dd1 = Lx - ds * t
    df_dd2 = ds * t
    # df/dds = delta*t - delta*sigm*(Lx/ds)
    df_dds = delta * t - delta * sigm * (Lx / ds)

    J = np.vstack([df_dd1, df_dd2, df_dds])  # (3, n)
    return J


def plot_uv_subtracted_only(
    df,
    bands=('u','g','r','i','z'),
    *,
    lambda_pivot,
    lam_s=2500.0,
    init_sigma=(0.0,0.0,0.1),
    init_tau=(0.0,0.0,0.1),
    bounds_sigma=((-6,6),(-6,6),(1e-3,3.0)),
    bounds_tau  =((-10,10),(-10,10),(1e-3,3.0)),
    fit_ds_sigma=True, ds_fixed_sigma=0.1,
    fit_ds_tau=True,   ds_fixed_tau=0.1,
    n_boot=300,
    colors=None,
    show=True,
    savepath_png=None,
    savepath_pdf=None,
):
    # ---------- helpers ----------
    def _require(name, provided):
        if provided is not None:
            return provided
        if name in globals():
            return globals()[name]
        raise ValueError(f"{name} must be provided or defined globally.")

    lambda_pivot = _require('lambda_pivot', lambda_pivot)
    colors = _require('colors', colors)

    # ---------- 1) Fit absolute data (kept) ----------
    fit_sigma = fit_slopes_broken(
        df, bands, lambda_pivot=lambda_pivot, lam_s=lam_s,
        init=init_sigma, bounds=bounds_sigma, target="sigma", return_errors=True,
        fit_ds=fit_ds_sigma, ds_fixed=ds_fixed_sigma,
        n_boot=n_boot,
    )
    fit_tau   = fit_slopes_broken(
        df, bands, lambda_pivot=lambda_pivot, lam_s=lam_s,
        init=init_tau, bounds=bounds_tau, target="tau", return_errors=True,
        fit_ds=fit_ds_tau, ds_fixed=ds_fixed_tau,
        n_boot=n_boot,
    )

    fit_sigma.update({"eta_sigma_blue":fit_sigma["d1"],
                      "eta_sigma_red":fit_sigma["d2"],
                      "eta_sigma_break":fit_sigma["ds"]})
    fit_tau.update({"eta_tau_blue":fit_tau["d1"],
                    "eta_tau_red":fit_tau["d2"],
                    "eta_tau_break":fit_tau["ds"]})

    # ---------- 2) Build UV-subtracted residual datasets ----------
    if "log_sigma_UV" not in df or "log_tau_UV_RF" not in df:
        raise KeyError("DataFrame must contain 'log_sigma_UV' and 'log_tau_UV_RF'.")

    def collect_residuals(target):
        lam_list, y_list, w_list = [], [], []
        if target == "sigma":
            stem_v, stem_e, base = "log_sigma_band_{}", "log_sigma_band_{}_err", "log_sigma_UV"
        else:
            stem_v, stem_e, base = "log_tau_band_{}_RF", "log_tau_band_{}_RF_err", "log_tau_UV_RF"

        for _, row in df.iterrows():
            z = float(row["z"])
            for b in bands:
                if b not in lambda_pivot: continue
                lam_rf = float(lambda_pivot[b]) / (1.0 + z)
                col_v = stem_v.format(b)
                if col_v not in df: continue
                yv = float(row[col_v]) - float(row[base])
                if not (np.isfinite(lam_rf) and np.isfinite(yv)): continue
                e = np.inf
                col_e = stem_e.format(b)
                if col_e in df:
                    ei = float(row[col_e])
                    if np.isfinite(ei) and ei > 0: e = ei
                w = 1.0 / max(e*e, 1e-12)
                lam_list.append(lam_rf); y_list.append(yv); w_list.append(w)

        return np.asarray(lam_list,float), np.asarray(y_list,float), np.asarray(w_list,float)

    lam_s_res, y_s_res, w_s_res = collect_residuals("sigma")
    lam_t_res, y_t_res, w_t_res = collect_residuals("tau")
    if lam_s_res.size < 3 or lam_t_res.size < 3:
        raise ValueError("Not enough UV-subtracted points to plot.")

    # ---------- 3) Intercepts (anchored once) ----------
    a_s_res = _global_intercept(
        y_s_res, lam_s_res, w_s_res, lam_s,
        fit_sigma['d1'], fit_sigma['d2'], fit_sigma['ds']
    )
    a_t_res = _global_intercept(
        y_t_res, lam_t_res, w_t_res, lam_s,
        fit_tau['d1'],   fit_tau['d2'],   fit_tau['ds']
    )

    # ---------- 4) x-grid (force pivot to be included exactly) ----------
    lam_all = np.concatenate([lam_s_res, lam_t_res, np.array([lam_s])])
    #xgrid = np.linspace(np.log10(lam_all.min()), np.log10(lam_all.max()), 600)
    xgrid = np.linspace(2.8, 4.2, 600)

    # splice in the exact pivot position
    xgrid = np.sort(np.unique(np.append(xgrid, np.log10(lam_s))))
    lam_grid = 10.0**xgrid

    # best-fit curves for residuals
    f_sig_best = log_broken_pl(lam_grid, lam_s,
                               fit_sigma['d1'], fit_sigma['d2'], fit_sigma['ds'])
    f_tau_best = log_broken_pl(lam_grid, lam_s,
                               fit_tau['d1'],   fit_tau['d2'],   fit_tau['ds'])
    yfit_sigma_res = a_s_res + f_sig_best
    yfit_tau_res   = a_t_res + f_tau_best

    # ---------- 5) 1σ envelope from parameter covariance (delta method) ----------
    def _std_from_cov(fit, lam_grid):
        # choose covariance
        cov_boot = fit.get("boot_cov", None)
        cov_hess = fit.get("cov", None)
        redchi   = float(fit.get("redchi", 1.0))
        ds_mode  = fit.get("ds_mode", "fit")

        cov_eff = None
        used_boot = False
        if cov_boot is not None and np.all(np.isfinite(cov_boot)):
            cov_eff = np.array(cov_boot, float)
            used_boot = True
        elif cov_hess is not None and np.all(np.isfinite(cov_hess)):
            cov_eff = np.array(cov_hess, float)

        if cov_eff is None:
            return None  # no covariance available

        # If boot cov is used, inflate by red-chi^2 to avoid too-tight bands
        if used_boot and np.isfinite(redchi) and redchi > 1.0:
            cov_eff = cov_eff * redchi

        # Reduce to 2x2 if ds was fixed
        if ds_mode == "fixed":
            cov_eff = cov_eff[:2, :2]

        d1, d2, ds = fit["d1"], fit["d2"], fit["ds"]
        Jfull = _jac_log_broken_pl(lam_grid, lam_s, d1, d2, ds)  # (3, n)
        if ds_mode == "fixed":
            J = Jfull[:2, :]  # (2, n)
        else:
            J = Jfull         # (3, n)

        # ensure SPD
        try:
            # small jitter in case of near-singularity
            jitter = 1e-12 * np.eye(cov_eff.shape[0])
            S = cov_eff + jitter
            # variance per x: sum_i sum_j J_i S_ij J_j
            var = np.einsum("in,ij,jn->n", J, S, J)
            std = np.sqrt(np.clip(var, 0.0, np.inf))
        except Exception:
            std = None
        return std

    # --- compute ±1σ envelopes on the same grid you plot ---
    std_sig = _std_from_cov(fit_sigma, lam_grid)
    std_tau = _std_from_cov(fit_tau,   lam_grid)

    # ---------- 6) Figure ----------
    fig, (ax_sr, ax_tr) = plt.subplots(
        2, 1, figsize=(6.2, 6.2), sharex=True, constrained_layout=True
    )
    fig.set_constrained_layout_pads(w_pad=0.01, h_pad=0.01, wspace=0.01, hspace=0.02)

    def inward(ax):
        ax.tick_params(direction='in', which='both', top=True, right=True, length=3, pad=2)
    for ax in (ax_sr, ax_tr):
        for s in ax.spines.values():
            s.set_linewidth(1.0)

    plotted_bands = []
    for b in [bb for bb in bands if bb in lambda_pivot]:
        # σ residuals
        col_s = f"log_sigma_band_{b}"
        if col_s in df:
            xs, ys = [], []
            for _, row in df.iterrows():
                z  = float(row['z'])
                lr = float(lambda_pivot[b]) / (1.0 + z)
                yv = float(row[col_s]) - float(row["log_sigma_UV"])
                if np.isfinite(lr) and np.isfinite(yv):
                    xs.append(np.log10(lr)); ys.append(yv)
            if xs:
                plotted_bands.append(b)
                ax_sr.scatter(np.array(xs), np.array(ys), s=14, alpha=0.5,
                              color=colors.get(b), edgecolor='none', zorder=1)

        # τ residuals
        col_t = f"log_tau_band_{b}_RF"
        if col_t in df:
            xs, ys = [], []
            for _, row in df.iterrows():
                z  = float(row['z'])
                lr = float(lambda_pivot[b]) / (1.0 + z)
                yv = float(row[col_t]) - float(row["log_tau_UV_RF"])
                if np.isfinite(lr) and np.isfinite(yv):
                    xs.append(np.log10(lr)); ys.append(yv)
            if xs:
                ax_tr.scatter(np.array(xs), np.array(ys), s=14, alpha=0.6,
                              color=colors.get(b), edgecolor='none', zorder=1)

    # --- shaded ±1σ bands (pinch at pivot) ---
    if std_sig is not None:
        ax_sr.fill_between(xgrid, yfit_sigma_res - std_sig, yfit_sigma_res + std_sig,
                           color='m', alpha=0.40, linewidth=0, zorder=4)
    if std_tau is not None:
        ax_tr.fill_between(xgrid, yfit_tau_res - std_tau, yfit_tau_res + std_tau,
                           color='m', alpha=0.40, linewidth=0, zorder=4)

    # model curves on top
    ax_sr.plot(xgrid, yfit_sigma_res, color='m', lw=1.6, zorder=5)
    ax_tr.plot(xgrid, yfit_tau_res,   color='m', lw=1.6, zorder=5)

    # styling
    for ax in (ax_sr, ax_tr):
        for s in ("top", "right"):
            ax.spines[s].set_visible(True)
        inward(ax)

    # axis labels
    ax_sr.set_ylabel(r'$\log(\sigma_{\mathrm{band}}/\sigma_{\mathrm{UV}})$')
    ax_tr.set_ylabel(r'$\log(\tau_{\mathrm{band,RF}}/\tau_{\mathrm{UV,RF}})$')
    ax_tr.set_xlabel(r'$\log_{10}\,\lambda_{\mathrm{RF}}\;(\mathrm{\AA})$')

    # secondary x-axis in Å
    def loglam_to_A(x): return np.power(10.0, x)
    def A_to_loglam(x): return np.log10(x)
    # --- secondary x-axis in Å (range-aware, clean ticks) ---

    secax = ax_sr.secondary_xaxis('top', functions=(loglam_to_A, A_to_loglam))
    secax.set_xlabel(r'$\lambda_{\mathrm{RF}}\;(\mathrm{\AA})$')
    secax.tick_params(direction='in', which='major', top=True)

    # compute nice, in-range tick positions in Å
    lam_min, lam_max = float(10**xgrid.min()), float(10**xgrid.max())
    span = lam_max - lam_min
    # pick a step that yields ~3–5 ticks
    candidates = np.array([500.0, 1000.0])
    step = candidates[np.argmin(np.abs(span / candidates - 4.0))]

    start = np.ceil(lam_min/step)*step
    stop  = np.floor(lam_max/step)*step
    ticks_A = np.arange(start, stop + 0.5*step, step)
    # keep only in-range (guards numerical noise)
    ticks_A = ticks_A[(ticks_A >= lam_min) & (ticks_A <= lam_max)]

    from matplotlib.ticker import FormatStrFormatter, FixedLocator, NullLocator
    secax.xaxis.set_major_locator(FixedLocator(ticks_A))
    secax.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
    secax.xaxis.set_minor_locator(NullLocator())  # no minor ticks on top


    # annotation blocks (unchanged formatters from your code)
    def _format_val_err_pair(v, e_pref, e_boot, default_fmt="+.1f"):
        if np.isfinite(e_boot) and (e_boot > 0): e_use = e_boot
        else: e_use = e_pref
        if np.isfinite(e_use) and e_use > 0:
            e_abs = float(abs(e_use))
            exp = int(np.floor(np.log10(e_abs)))
            lead = int(np.floor(e_abs / (10.0**exp)))
            n_sig = 2 if lead in (1, 2) else 1
            dp = -(exp) + (n_sig - 1)
            v_r = np.round(v,  dp)
            e_r = np.round(e_use, dp)
            dec = max(0, dp)
            v_str = f"{v_r:+.{dec}f}"
            e_str = f"{e_r:.{dec}f}"
            ok = True
        else:
            v_str = f"{v:{default_fmt}}"; e_str = ""; ok = False
        return v_str, e_str, ok

    def _fmt_eta_block(prefix, fit):
        v1, e1, ok1 = _format_val_err_pair(fit["d1"], fit.get("d1_err", np.nan), fit.get("d1_boot_err", np.nan), default_fmt=".1f")
        v2, e2, ok2 = _format_val_err_pair(fit["d2"], fit.get("d2_err", np.nan), fit.get("d2_boot_err", np.nan), default_fmt=".1f")
        v3, e3, ok3 = _format_val_err_pair(fit["ds"], fit.get("ds_err", np.nan), fit.get("ds_boot_err", np.nan), default_fmt=".1f")
        s1 = (f"{v1}" + (f"±{e1}" if ok1 else ""))
        s2 = (f"{v2}" + (f"±{e2}" if ok2 else ""))
        s3 = (f"{v3}" + (f"±{e3}" if ok3 else ""))
        return (fr'$\eta_{{\{prefix},\mathrm{{blue}}}}$ = {s1}' "\n"
                fr'$\eta_{{\{prefix},\mathrm{{red}}}}$  = {s2}' "\n"
                fr'$\eta_{{\{prefix},\mathrm{{break}}}}$ = {s3}')
    print(_fmt_eta_block("sigma", fit_sigma))
    print(_fmt_eta_block("tau", fit_tau))

    # ax_sr.text(0.02, 0.04, _fmt_eta_block("sigma", fit_sigma),
    #            transform=ax_sr.transAxes, va='bottom', ha='left', fontsize=10,
    #            bbox=dict(boxstyle='round', fc='w', ec='0.75', alpha=0.9), zorder=10)
    # ax_tr.text(0.02, 0.96, _fmt_eta_block("tau", fit_tau),
    #            transform=ax_tr.transAxes, va='top', ha='left', fontsize=10,
    #            bbox=dict(boxstyle='round', fc='w', ec='0.75', alpha=0.9), zorder=10)

    # legend
    band_handles = [Line2D([0],[0], linestyle='none', marker='o', markersize=6,
                           markerfacecolor=colors.get(b), markeredgecolor='none',
                           label=f'{b}-band')
                    for b in dict.fromkeys(plotted_bands)]
    model_handle = [Line2D([0],[0], color='m', lw=1.6, label='Population fit')]
    if band_handles:
        ax_sr.legend(handles=band_handles + model_handle, loc='upper right',
                     frameon=False, ncol=2, fontsize=9)
    #ax_sr.set_xlim(3.11, 3.89)
    ax_sr.set_ylim(-0.49, 0.51)
    ax_tr.set_xlim(3.12, 3.78)
    ax_tr.set_ylim(-0.49, 0.61)

    # save/show
    if savepath_png: plt.savefig(savepath_png, dpi=600)
    if savepath_pdf: plt.savefig(savepath_pdf, dpi=600)
    if show: plt.show()
    plt.close()

    return fit_sigma, fit_tau


fit_sigma, fit_tau = plot_uv_subtracted_only(
    df_agn,
    bands=('u','g','r','i','z'),
    lambda_pivot=lambda_pivot,
    lam_s=2500.0,
    init_sigma=(0.0, 0.0, 0.1),
    init_tau=(0.0, 0.0, 0.1),
    fit_ds_sigma=False, ds_fixed_sigma=0.1,
    fit_ds_tau=False,   ds_fixed_tau=0.1,
    n_boot=300,  
    savepath_png="plots/appendix/broken_pl_fit.png",
    savepath_pdf="plots/appendix/sigma_tau_vs_lambda_broken_pl_fit.pdf",
)
# Out:
# $\eta_{\sigma,\mathrm{blue}}$ = -0.698±0.016
# $\eta_{\sigma,\mathrm{red}}$  = -0.610±0.018
# $\eta_{\sigma,\mathrm{break}}$ = +0.1000000000000000±0.0000000000000005
# $\eta_{\tau,\mathrm{blue}}$ = +0.42±0.04
# $\eta_{\tau,\mathrm{red}}$  = +0.49±0.04
# $\eta_{\tau,\mathrm{break}}$ = +0.1000000000000000±0.0000000000000005

# %%
lambda_pivot = {
    'u': 3543,  # SDSS u-band
    'g': 4770,  # SDSS g-band
    'r': 6231,  # SDSS r-band
    'i': 7625,  # SDSS i-band
    'z': 9134,  # SDSS z-band
    'y': 9633,  # PS1 y-band
}

colors = {
    'u': 'tab:blue',
    'g': 'tab:green', 
    'r': 'tab:orange', 
    'i': 'tab:red', 
    'z': 'tab:brown', 
    'y': 'tab:gray'
}


def log_broken_pl(lam, lam_s, d1, d2, ds):
    """
    Log10 of a smooth broken power-law, normalized to 0 at lam_s.
    ds is a smoothness (larger ds => smoother transition).
    This version is numerically stable and AD-friendly.
    """
    # Preconditions: lam>0, lam_s>0, ds>0 (enforce in your priors/transforms)
    ln10 = np.log(10.0)

    # Work in log-space: log10(x) with x=lam/lam_s
    log10x = (np.log(lam) - np.log(lam_s)) / ln10
    # a = log10(x)/ds; we need log10(1 + 10^a) stably
    a = log10x / ds
    # log10(1 + 10^a) = log(1 + exp(a*ln 10)) / ln 10, computed stably:
    log10_1p10a = np.logaddexp(0.0, a * ln10) / ln10

    delta = d2 - d1
    # Your original: d1*log10(x) + (delta/smooth_exp)*log10_1px - (delta/smooth_exp)*log10(2)
    # with smooth_exp=1/ds  => (delta*ds)*(...)
    log_f = d1 * log10x + (delta * ds) * (log10_1p10a - np.log10(2.0))
    return log_f

def log_single_pl(lam, lam_s, d, *_, **__):
    """
    Log10 of a simple power-law, normalized to 0 at lam_s.
    Slope is d everywhere.

    Notes:
    - Works for array lam/lam_s; requires lam>0, lam_s>0 (enforce upstream).
    - Uses log-space to avoid overflow in lam/lam_s.
    - Swallows extra args (*_, **__) so you can call it with the same
      signature as your broken-PL without recompiles.
    """
    ln10 = np.log(np.array(10.0, dtype=np.result_type(lam, lam_s, d)))
    # log10(lam/lam_s) = (log(lam) - log(lam_s)) / ln(10)
    return d * (np.log(lam) - np.log(lam_s)) / ln10



from matplotlib.lines import Line2D
from matplotlib.patches import Patch

def plot_sigma_tau_vs_lambda_with_model(
    df,
    bands=('u', 'g', 'r', 'i', 'z'),
    *,
    residual=False,      # subtract UV from BOTH σ and τ
    col_tau_uv=None,     # override UV τ column name (default auto-detect)
    col_sigma_uv=None,   # override UV σ column name (default auto-detect)
    show=True,
    debug=False,
    broken_pl=False,
):
    """
    Plot log10 σ_band and log10 τ_band,RF vs log10 λ_RF with population ribbons.

    Needs per-row: lam_s, eta_A1, eta_A2, eta_tau1, eta_tau2, eta_break,
                   log_sigma0, log_tau_drw0, z,
                   and per-band: log_sigma_band_{b}, log_tau_band_{b}_RF.
    If residual=True, also needs UV references:
      τ UV column (auto): 'log_tau_UV_RF' then 'log_tau_UV'
      σ UV column (auto): 'log_sigma_UV'  then 'log_sigma_UV_RF'
    """

    tau_uv = df['log_tau_UV_RF']
    sig_uv = df['log_sigma_UV']

    # ---- figure ----
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6.2, 6.2),
                                   sharex=True, constrained_layout=True)
    fig.set_constrained_layout_pads(w_pad=0.01, h_pad=0.01, wspace=0.01, hspace=0.02)

    def inward(ax):
        ax.tick_params(direction='in', which='both', top=True, right=True, length=3, pad=2)
        for s in ax.spines.values():
            s.set_linewidth(1.0)

    # ---- scatter ----
    x_all, x_all_tau, y_all_tau = [], [], []
    plotted_bands = []  # track which bands actually plotted for legend

    for b in bands:
        if b not in lambda_pivot or f'log_sigma_band_{b}' not in df or f'log_tau_band_{b}_RF' not in df:
            continue

        lam_rf = np.asarray(lambda_pivot[b]) / (1.0 + df['z'].to_numpy())
        x = np.log10(lam_rf)

        y_sigma = df[f'log_sigma_band_{b}'].to_numpy()
        y_tau_abs = df[f'log_tau_band_{b}_RF'].to_numpy()

        if residual:
            y_sigma = y_sigma - sig_uv
            y_tau   = y_tau_abs - tau_uv
        else:
            y_tau = y_tau_abs

        m1 = np.isfinite(x) & np.isfinite(y_sigma)
        m2 = np.isfinite(x) & np.isfinite(y_tau)

        if m1.any() or m2.any():
            plotted_bands.append(b)

        ax1.scatter(x[m1], y_sigma[m1], s=14, alpha=0.6, color=colors.get(b),
                    edgecolor='none', zorder=1)
        ax2.scatter(x[m2], y_tau[m2],   s=14, alpha=0.6, color=colors.get(b),
                    edgecolor='none', zorder=1)

        x_all.append(x[m1])
        x_all_tau.append(x[m2]); y_all_tau.append(y_tau[m2])

    x_all = np.concatenate(x_all) if any(len(a) for a in x_all) else np.array([])
    x_all_tau = np.concatenate(x_all_tau) if any(len(a) for a in x_all_tau) else np.array([])
    y_all_tau = np.concatenate(y_all_tau) if any(len(a) for a in y_all_tau) else np.array([])

    # if x_all.size:
    #     xmin, xmax = float(np.nanmin(x_all)), float(np.nanmax(x_all))
    #     ax2.set_xlim(xmin, xmax)
    # else:
    xmin, xmax = 2.8, 4.0

    # ---- model ribbons ----
    lam_grid = np.linspace(10**xmin, 10**xmax, 400).astype(float)
    loglam_grid = np.log10(lam_grid)

    power_law = log_single_pl if not broken_pl else log_broken_pl
    model_sigma_all, model_tau_all = [], []
    for _, row in df.iterrows():
        ds = float(row['eta_break'])
        shp_sigma = power_law(lam_grid, row['lam_s'], row['eta_A1'],  row['eta_A2'],  ds)
        shp_tau   = power_law(lam_grid, row['lam_s'], row['eta_tau1'], row['eta_tau2'], ds)

        sig0_10 = float(row['log_sigma0'])
        tau0_10 = float(row['log_tau_drw0']) - np.log10(1.0 + float(row['z']))  # rest-frame τ

        if residual:
            # subtract this row's UV references from intercepts
            sig0_10 -= float(row.get(col_sigma_uv, row.get('log_sigma_UV',
                                row.get('log_sigma_UV_RF', 0.0))))
            tau0_10 -= float(row.get(col_tau_uv,   row.get('log_tau_UV_RF',
                                row.get('log_tau_UV', 0.0))))

        model_sigma_all.append(sig0_10 + shp_sigma)
        model_tau_all.append(tau0_10 + shp_tau)

    model_sigma_all = np.asarray(model_sigma_all)
    model_tau_all   = np.asarray(model_tau_all)

    mu_s, sd_s = np.nanmean(model_sigma_all, axis=0), np.nanstd(model_sigma_all, axis=0)
    ax1.plot(loglam_grid, mu_s, color='m', lw=1.5, zorder=5)
    ax1.fill_between(loglam_grid, mu_s - sd_s, mu_s + sd_s, color='m', alpha=0.3, zorder=4)

    mu_t, sd_t = np.nanmean(model_tau_all, axis=0), np.nanstd(model_tau_all, axis=0)
    ax2.plot(loglam_grid, mu_t, color='m', lw=1.5, zorder=5)
    ax2.fill_between(loglam_grid, mu_t - sd_t, mu_t + sd_t, color='m', alpha=0.3, zorder=4)

    # ---- labels & axes ----
    if residual:
        sig_lab = r'$\log(\sigma_{\mathrm{band}}/\sigma_{\mathrm{UV}})$'
        tau_lab = r'$\log(\tau_{\mathrm{band,RF}}/\tau_{\mathrm{UV,RF}})$'
    else:
        sig_lab = r'$\log\!\,\sigma_{\mathrm{band}}$'
        tau_lab = r'$\log\!\,\tau_{\mathrm{band,RF}}$'

    ax1.set_ylabel(sig_lab)
    ax2.set_ylabel(tau_lab)
    ax2.set_xlabel(r'$\log(\lambda_{\mathrm{RF}}/\mathrm{\AA})$')
    ax1.set_xlim(3.11, 3.89)
    ax2.set_xlim(3.11, 3.89)

    inward(ax1); inward(ax2)

    # top linear-Å axis
    def loglam_to_A(x): return np.power(10.0, x)
    def A_to_loglam(x): return np.log10(x)
    secax = ax1.secondary_xaxis('top', functions=(loglam_to_A, A_to_loglam))
    secax.set_xlabel(r'$\lambda_{\mathrm{RF}}\;(\mathrm{\AA})$')
    secax.tick_params(direction='in', which='both', top=True)

    lam_min, lam_max = 10**xmin, 10**xmax
    rng = lam_max - lam_min
    steps = np.array([2000], dtype=float)
    step = steps[np.argmin(np.abs(rng / steps - 5.0))]
    ticks = np.arange(np.floor(lam_min / step) * step,
                      np.ceil(lam_max / step) * step + step, step)
    secax.set_xticks(np.union1d(ticks, [1000, 2000.0]))

    # ---- legend (bands + model) ----
    band_handles = [
        Line2D([0], [0], linestyle='none', marker='o', markersize=6,
               markerfacecolor=colors.get(b), markeredgecolor='none',
               label=f'{b}-band')
        for b in plotted_bands
    ]
    model_handles = []
    model_handles.append(Line2D([0], [0], color='m', lw=1.5, label='Model mean'))

    handles = band_handles + model_handles
    ax1.legend(handles=handles, loc='best', frameon=False, ncol=2, fontsize=9)


    plt.savefig('plots/appendix/sigma_tau_vs_lambda.png', dpi=600)
    plt.savefig('plots/appendix/sigma_tau_vs_lambda.pdf', dpi=600)
    if show:
        plt.show()
    plt.close()


plot_sigma_tau_vs_lambda_with_model(df_agn_all, residual=True, broken_pl=False)
# Out:
# /tmp/ipykernel_60722/660329476.py:194: RuntimeWarning: divide by zero encountered in log10
#   def A_to_loglam(x): return np.log10(x)
# /tmp/ipykernel_60722/660329476.py:194: RuntimeWarning: divide by zero encountered in log10
#   def A_to_loglam(x): return np.log10(x)

# %%
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

cols = ['eta_A1', 'eta_A2', 'eta_tau1', 'eta_tau2']
#cols = ['eta_A1', 'eta_tau1']

fig, axes = plt.subplots(1, len(cols), figsize=(len(cols)*5, 4), sharex=False, sharey=False)

#cols = ['eta_A1', 'eta_tau1']
#cols = ['eta_A1_mean', 'eta_A2_mean', 'eta_tau1_mean', 'eta_tau2_mean']



mask = np.ones(len(df_agn), dtype=bool)
rhat_lim = 1.1
# mask &= ((df_agn['eta_tau2_rhat'] < rhat_lim) & (df_agn['eta_tau1_rhat'] < rhat_lim) 
#     & (df_agn['eta_A1_rhat'] < rhat_lim) & (df_agn['eta_A2_rhat'] < rhat_lim)
#     )
# # Apply additional mask for per-chain variance to all eta fields
# for field in ['eta_tau1', 'eta_tau2', 'eta_A1', 'eta_A2']:
#     mask &= (df_agn[f'{field}_per_chain_variance_max'] < 2.5)

latex_labels = {
    'eta_A1': r'$A_1$',
    'eta_A2': r'$A_2$',
    'eta_tau1': r'$\tau_1$',
    'eta_tau2': r'$\tau_2$'
}

for i, (col, color) in enumerate(zip(cols, colors)):
    data = df_agn.loc[mask, col].dropna()
    median = data.median()
    err = data.std()  # / np.sqrt(len(data))
    axes[i].hist(data, bins=30, color=color, alpha=0.7)

    # Add vertical lines for injected slopes

    axes[i].axvline(median, color='k', linestyle='--', label=f'Median: {median:.3g}')
    label = latex_labels.get(col, col)
    textstr = f"{label} = {median:.3f} ± {err:.3f}"
    # if injected_label is not None:
    #     textstr += f"\n{injected_label} = {injected_val:.3f}"
    axes[i].annotate(
        textstr,
        xy=(0.97, 0.97), xycoords='axes fraction',
        fontsize=16,
        ha='right', va='top',
        bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8)
    )  
    
    axes[i].set_xlabel(label)
    if i == 0:
        axes[i].set_ylabel('Count')

    #axes[i].legend(fontsize=12)

#axes[2].set_xlim(-2, 5)


plt.tight_layout()
#os.makedirs("results/plots/send", exist_ok=True)
#plt.savefig(f"results/plots/send/{prefix}_etas_hist.png", dpi=200)
plt.show()
